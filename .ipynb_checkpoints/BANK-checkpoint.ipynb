# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Users\fares\anaconda3\envs\pycaret-env\python.exe
# 3.11.13 | packaged by Anaconda, Inc. | (main, Jun  5 2025, 13:03:15) [MSC v.1929 64 bit (AMD64)]

# %%
import pandas as pd
df = pd.read_csv("C:/Users/fares/Desktop/LaPlateforme/IA/Bank Marketing/bank-marketing/data/bank-additional-full.csv", sep=';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
X = df.drop("y", axis=1)
y = df["y"]

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.apply(lambda col: col.isin(["unknown"]).sum())
# Out:
# age                  0
# job                330
# marital             80
# education         1731
# default           8597
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# dtype: int64

# %%
df = df.replace("unknown", "missing")

# %%
df.apply(lambda col: col.isin(["unknown"]).sum())
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
import numpy
import scipy
print(numpy.__version__)
print(scipy.__version__)
# Out:
# 1.26.4
# 1.10.1

# %%
from pycaret.classification import *
setup(data=df, target='y')
# Out:
# <style type="text/css">
# #T_e1158_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e1158">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1158_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e1158_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1158_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1158_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e1158_row0_col1" class="data row0 col1" >4943</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1158_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e1158_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1158_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e1158_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1158_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_e1158_row3_col1" class="data row3 col1" >no: 0, yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1158_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_e1158_row4_col1" class="data row4 col1" >(41188, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e1158_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_e1158_row5_col1" class="data row5 col1" >(41188, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e1158_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_e1158_row6_col1" class="data row6 col1" >(28831, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e1158_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_e1158_row7_col1" class="data row7 col1" >(12357, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e1158_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_e1158_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e1158_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_e1158_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e1158_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_e1158_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e1158_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_e1158_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e1158_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_e1158_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e1158_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_e1158_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e1158_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_e1158_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e1158_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_e1158_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e1158_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_e1158_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e1158_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_e1158_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e1158_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_e1158_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e1158_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_e1158_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e1158_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_e1158_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e1158_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_e1158_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e1158_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e1158_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_e1158_row22_col1" class="data row22 col1" >dc00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Recherche de mineurs

# %%
(df["age"] < 18).sum()
# Out:
# 5

# %% [markdown]
# On affiche les 5 pour avoir toutes leur données

# %%
df[df["age"] < 18]
# Out:
#        age      job marital education default  housing     loan   contact  \
# 37140   17  student  single   missing      no      yes       no  cellular
# 37539   17  student  single  basic.9y      no      yes       no  cellular
# 37558   17  student  single  basic.9y      no      yes       no  cellular
# 37579   17  student  single  basic.9y      no  missing  missing  cellular
# 38274   17  student  single   missing      no       no      yes  cellular
#
#       month day_of_week  ...  campaign  pdays  previous  poutcome  \
# 37140   aug         wed  ...         3      4         2   success
# 37539   aug         fri  ...         2    999         2   failure
# 37558   aug         fri  ...         3      4         2   success
# 37579   aug         fri  ...         2    999         1   failure
# 38274   oct         tue  ...         1      2         2   success
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 37140         -2.9          92.201          -31.4      0.884       5076.2   no
# 37539         -2.9          92.201          -31.4      0.869       5076.2   no
# 37558         -2.9          92.201          -31.4      0.869       5076.2   no
# 37579         -2.9          92.201          -31.4      0.869       5076.2  yes
# 38274         -3.4          92.431          -26.9      0.742       5017.5  yes
#
# [5 rows x 21 columns]

# %% [markdown]
# 5 individus âgés de 17 ans ont été détectés. Bien que l’ouverture d’un compte soit possible avec autorisation parentale, le démarchage actif pour un produit financier (dépôt à terme) sans consentement explicite n’est pas légalement autorisé. Nous avons donc choisi de les exclure par précaution

# %%
df = df[df["age"] >= 18]

# %% [markdown]
# On verifie que c'est bien supprimer

# %%
(df["age"] < 18).sum()
# Out:
# 0

# %%
from pycaret.classification import *

setup(data=df, target='y', session_id=123)
# Out:
# <style type="text/css">
# #T_97830_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_97830">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97830_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_97830_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97830_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97830_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_97830_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97830_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_97830_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97830_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_97830_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97830_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_97830_row3_col1" class="data row3 col1" >no: 0, yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97830_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_97830_row4_col1" class="data row4 col1" >(41183, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_97830_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_97830_row5_col1" class="data row5 col1" >(41183, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_97830_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_97830_row6_col1" class="data row6 col1" >(28828, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_97830_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_97830_row7_col1" class="data row7 col1" >(12355, 63)</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_97830_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_97830_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_97830_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_97830_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_97830_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_97830_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_97830_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_97830_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_97830_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_97830_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_97830_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_97830_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_97830_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_97830_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_97830_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_97830_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_97830_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_97830_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_97830_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_97830_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_97830_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_97830_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_97830_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_97830_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_97830_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_97830_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_97830_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_97830_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_97830_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_97830_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_97830_row22_col1" class="data row22 col1" >d755</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_c9124 th {
#   text-align: left;
# }
# #T_c9124_row0_col0, #T_c9124_row0_col2, #T_c9124_row0_col4, #T_c9124_row0_col5, #T_c9124_row0_col6, #T_c9124_row0_col7, #T_c9124_row1_col0, #T_c9124_row1_col1, #T_c9124_row1_col3, #T_c9124_row2_col0, #T_c9124_row2_col1, #T_c9124_row2_col2, #T_c9124_row2_col3, #T_c9124_row2_col4, #T_c9124_row2_col5, #T_c9124_row2_col6, #T_c9124_row2_col7, #T_c9124_row3_col0, #T_c9124_row3_col1, #T_c9124_row3_col2, #T_c9124_row3_col3, #T_c9124_row3_col4, #T_c9124_row3_col5, #T_c9124_row3_col6, #T_c9124_row3_col7, #T_c9124_row4_col0, #T_c9124_row4_col1, #T_c9124_row4_col2, #T_c9124_row4_col3, #T_c9124_row4_col4, #T_c9124_row4_col5, #T_c9124_row4_col6, #T_c9124_row4_col7, #T_c9124_row5_col0, #T_c9124_row5_col1, #T_c9124_row5_col2, #T_c9124_row5_col3, #T_c9124_row5_col4, #T_c9124_row5_col5, #T_c9124_row5_col6, #T_c9124_row5_col7, #T_c9124_row6_col0, #T_c9124_row6_col1, #T_c9124_row6_col2, #T_c9124_row6_col3, #T_c9124_row6_col4, #T_c9124_row6_col5, #T_c9124_row6_col6, #T_c9124_row6_col7, #T_c9124_row7_col0, #T_c9124_row7_col1, #T_c9124_row7_col2, #T_c9124_row7_col3, #T_c9124_row7_col4, #T_c9124_row7_col5, #T_c9124_row7_col6, #T_c9124_row7_col7, #T_c9124_row8_col0, #T_c9124_row8_col1, #T_c9124_row8_col2, #T_c9124_row8_col3, #T_c9124_row8_col4, #T_c9124_row8_col5, #T_c9124_row8_col6, #T_c9124_row8_col7, #T_c9124_row9_col0, #T_c9124_row9_col1, #T_c9124_row9_col2, #T_c9124_row9_col3, #T_c9124_row9_col4, #T_c9124_row9_col5, #T_c9124_row9_col6, #T_c9124_row9_col7, #T_c9124_row10_col0, #T_c9124_row10_col1, #T_c9124_row10_col2, #T_c9124_row10_col3, #T_c9124_row10_col4, #T_c9124_row10_col5, #T_c9124_row10_col6, #T_c9124_row10_col7, #T_c9124_row11_col0, #T_c9124_row11_col1, #T_c9124_row11_col2, #T_c9124_row11_col3, #T_c9124_row11_col4, #T_c9124_row11_col5, #T_c9124_row11_col6, #T_c9124_row11_col7, #T_c9124_row12_col0, #T_c9124_row12_col1, #T_c9124_row12_col2, #T_c9124_row12_col3, #T_c9124_row12_col4, #T_c9124_row12_col5, #T_c9124_row12_col6, #T_c9124_row12_col7, #T_c9124_row13_col0, #T_c9124_row13_col1, #T_c9124_row13_col2, #T_c9124_row13_col3, #T_c9124_row13_col4, #T_c9124_row13_col5, #T_c9124_row13_col6, #T_c9124_row13_col7 {
#   text-align: left;
# }
# #T_c9124_row0_col1, #T_c9124_row0_col3, #T_c9124_row1_col2, #T_c9124_row1_col4, #T_c9124_row1_col5, #T_c9124_row1_col6, #T_c9124_row1_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c9124_row0_col8, #T_c9124_row1_col8, #T_c9124_row2_col8, #T_c9124_row3_col8, #T_c9124_row4_col8, #T_c9124_row5_col8, #T_c9124_row6_col8, #T_c9124_row7_col8, #T_c9124_row8_col8, #T_c9124_row9_col8, #T_c9124_row11_col8, #T_c9124_row12_col8, #T_c9124_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c9124_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c9124">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9124_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c9124_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c9124_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c9124_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c9124_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c9124_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c9124_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c9124_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_c9124_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9124_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_c9124_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_c9124_row0_col1" class="data row0 col1" >0.9156</td>
#       <td id="T_c9124_row0_col2" class="data row0 col2" >0.9458</td>
#       <td id="T_c9124_row0_col3" class="data row0 col3" >0.9156</td>
#       <td id="T_c9124_row0_col4" class="data row0 col4" >0.9085</td>
#       <td id="T_c9124_row0_col5" class="data row0 col5" >0.9107</td>
#       <td id="T_c9124_row0_col6" class="data row0 col6" >0.5303</td>
#       <td id="T_c9124_row0_col7" class="data row0 col7" >0.5363</td>
#       <td id="T_c9124_row0_col8" class="data row0 col8" >0.6200</td>
#     </tr>
#     <tr>
#       <th id="T_c9124_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_c9124_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c9124_row1_col1" class="data row1 col1" >0.9150</td>
#       <td id="T_c9124_row1_col2" class="data row1 col2" >0.9491</td>
#       <td id="T_c9124_row1_col3" class="data row1 col3" >0.9150</td>
#       <td id="T_c9124_row1_col4" class="data row1 col4" >0.9099</td>
#       <td id="T_c9124_row1_col5" class="data row1 col5" >0.9118</td>
#       <td id="T_c9124_row1_col6" class="data row1 col6" >0.5434</td>
#       <td id="T_c9124_row1_col7" class="data row1 col7" >0.5463</td>
#       <td id="T_c9124_row1_col8" class="data row1 col8" >0.2500</td>
#     </tr>
#     <tr>
#       <th id="T_c9124_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_c9124_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_c9124_row2_col1" class="data row2 col1" >0.9116</td>
#       <td id="T_c9124_row2_col2" class="data row2 col2" >0.9396</td>
#       <td id="T_c9124_row2_col3" class="data row2 col3" >0.9116</td>
#       <td id="T_c9124_row2_col4" class="data row2 col4" >0.9016</td>
#       <td id="T_c9124_row2_col5" class="data row2 col5" >0.9037</td>
#       <td id="T_c9124_row2_col6" class="data row2 col6" >0.4833</td>
#       <td id="T_c9124_row2_col7" class="data row2 col7" >0.4953</td>
#       <td id="T_c9124_row2_col8" class="data row2 col8" >0.3580</td>
#     </tr>
#     <tr>
#       <th id="T_c9124_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_c9124_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_c9124_row3_col1" class="data row3 col1" >0.9103</td>
#       <td id="T_c9124_row3_col2" class="data row3 col2" >0.9319</td>
#       <td id="T_c9124_row3_col3" class="data row3 col3" >0.9103</td>
#       <td id="T_c9124_row3_col4" class="data row3 col4" >0.8991</td>
#       <td id="T_c9124_row3_col5" class="data row3 col5" >0.9008</td>
#       <td id="T_c9124_row3_col6" class="data row3 col6" >0.4623</td>
#       <td id="T_c9124_row3_col7" class="data row3 col7" >0.4784</td>
#       <td id="T_c9124_row3_col8" class="data row3 col8" >5.8920</td>
#     </tr>
#     <tr>
#       <th id="T_c9124_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_c9124_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_c9124_row4_col1" class="data row4 col1" >0.9089</td>
#       <td id="T_c9124_row4_col2" class="data row4 col2" >0.9330</td>
#       <td id="T_c9124_row4_col3" class="data row4 col3" >0.9089</td>
#       <td id="T_c9124_row4_col4" class="data row4 col4" >0.9024</td>
#       <td id="T_c9124_row4_col5" class="data row4 col5" >0.9048</td>
#       <td id="T_c9124_row4_col6" class="data row4 col6" >0.5045</td>
#       <td id="T_c9124_row4_col7" class="data row4 col7" >0.5080</td>
#       <td id="T_c9124_row4_col8" class="data row4 col8" >0.1780</td>
#     </tr>
#     <tr>
#       <th id="T_c9124_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_c9124_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_c9124_row5_col1" class="data row5 col1" >0.9084</td>
#       <td id="T_c9124_row5_col2" class="data row5 col2" >0.9367</td>
#       <td id="T_c9124_row5_col3" class="data row5 col3" >0.9084</td>
#       <td id="T_c9124_row5_col4" class="data row5 col4" >0.8966</td>
#       <td id="T_c9124_row5_col5" class="data row5 col5" >0.8987</td>
#       <td id="T_c9124_row5_col6" class="data row5 col6" >0.4501</td>
#       <td id="T_c9124_row5_col7" class="data row5 col7" >0.4662</td>
